# %%
# added by PWL to force images to be downloaded before test starts
import glob
from IPython.display import HTML
png_list = glob.glob("*.png")
image_list = ""
for png in png_list:
    image_list+=f"<image src='{png}' width='5px' >"
display(HTML('<p>'+image_list+'</p>'))
# Out:
# <p><image src='image26.png' width='5px' ><image src='image5.png' width='5px' ><image src='image16.png' width='5px' ><image src='image6.png' width='5px' ><image src='image13.png' width='5px' ><image src='image15.png' width='5px' ><image src='image3.png' width='5px' ><image src='image9.png' width='5px' ><image src='image12.png' width='5px' ><image src='image25.png' width='5px' ><image src='image1.png' width='5px' ><image src='image19.png' width='5px' ><image src='image14.png' width='5px' ><image src='image7.png' width='5px' ><image src='image4.png' width='5px' ><image src='image22.png' width='5px' ><image src='image20.png' width='5px' ><image src='image17.png' width='5px' ><image src='image18.png' width='5px' ><image src='image8.png' width='5px' ><image src='image24.png' width='5px' ><image src='image2.png' width='5px' ><image src='image30.png' width='5px' ><image src='image10.png' width='5px' ><image src='image11.png' width='5px' ><image src='image21.png' width='5px' ><image src='imag
# ...

# %%
#Imports 
from IPython.display import display, HTML, Image, clear_output
import time
import random
import ipywidgets as widgets
from jupyter_ui_poll import ui_events
import requests
from bs4 import BeautifulSoup
import json

#Defining all Images
image1 = Image("image1.png", width = 700)
image2 = Image("image2.png", width = 700)
image3 = Image("image3.png", width = 700)
image4 = Image("image4.png", width = 700)
image5 = Image("image5.png", width = 700)
image6 = Image("image6.png", width = 700)
image7 = Image("image7.png", width = 700)
image8 = Image("image8.png", width = 700)
image9 = Image("image9.png", width = 700)
image10 = Image("image10.png", width = 700)
image11 = Image("image11.png", width = 700)
image12 = Image("image12.png", width = 700)
image13 = Image("image13.png", width = 700)
image14 = Image("image14.png", width = 700)
image15 = Image("image15.png", width = 700)
image16 = Image("image16.png", width = 700)
image17 = Image("image17.png", width = 700)
image18 = Image("image18.png", width = 700)
image19 = Image("image19.png", width = 700)
image20 = Image("image20.png", width = 700)
image21 = Image("image21.png", width = 700)
image22 = Image("image22.png", width = 700)
image23 = Image("image23.png", width = 700)
image24 = Image("image24.png", width = 700)
image25 = Image("image25.png", width = 700)
image26 = Image("image26.png", width = 700)
image27 = Image("image27.png", width = 700)
image28 = Image("image28.png", width = 700)
image29 = Image("image29.png", width = 700)
image30 = Image("image30.png", width = 700)


#List of Images 
images = [image1, image2, image3, image4, image5, image6, image7, image8, image9, image10,
          image11, image12, image13, image14, image15, image16, image17, image18, image19, image20,
         image21, image22, image23, image24, image25, image26, image27, image28, image29, image30]


answers = ["Left", "Right", "Right", "Left", "Left", 
           "Right", "Left", "Right", "Right", "Right", 
           "Left", "Left", "Left", "Right", "Right",
           "Right", "Right", "Left", "Left","Right",
           "Left", "Left", "Left", "Left", "Left", 
           "Left", "Left",  "Right", "Left", "Left" ] 

#Data Consent Information
data_consent_info = """DATA CONSENT INFORMATION:
Please read:
we wish to record your response data
to an anonymised public data repository.
Your data will be used for educational teaching purposes
practising data analysis and visualisation.
Please type yes in the box below if you consent to the upload."""

print(data_consent_info)
result = input("> ")

if result == "yes":
    print("Thanks for your participation.")
    print("Please contact philip.lewis@ucl.ac.uk")
    print("If you have any questions or concerns")
    print("regarding the stored results.")

else:
    raise(Exception("User did not consent to continue test."))

time.sleep(3)
clear_output(wait=False)
time.sleep(0.1)

#Instructions for inputting ID
id_instructions = """

Enter your anonymised ID

To generate an anonymous 4-letter unique user identifier please enter:

- two letters based on the initials (first and last name) of a childhood friend

- two letters based on the initials (first and last name) of a favourite actor / actress

e.g. if your friend was called Charlie Brown and film star was Tom Cruise

then your unique identifer would be CBTC

"""
#Want to add some more stuff in here about gender age, course 

print(id_instructions)
user_id = input("> ").lower()
print("User entered id:", user_id)
clear_output(wait=False)
time.sleep(0.1)

#Instructions for inputting gender
gender_instructions = """

Please enter the following information about your gender:


Please input M for Male, F for Female and P if you would prefer not to say. 

"""

print(gender_instructions)
user_gender = input("> ")
clear_output(wait=False)
time.sleep(0.1)

#Instructions for inputting age
age_instructions = """

Please enter your age below: 
"""
time.sleep(0.1)

print(age_instructions)
user_age = input("> ")
clear_output(wait=False)
time.sleep(0.1)

#Instructions for inputting course
course_instructions = """

Please enter the course you are taking in the Division of Biosciences:

"""

print(course_instructions)
user_course = input("> ")
clear_output(wait=False)
time.sleep(0.1)

tiredness_instructions = """

Finally, please let us know what level of tiredness you are feeling today:

Enter your answer as a number 1-5:

1 - actually falling asleep right now
2 - significantly tired
3 - a little tired
4 - not tired
5 - totally wired and almost too awake

"""

print(tiredness_instructions)
user_tiredness = input("> ")
clear_output(wait=False)
time.sleep(0.1)
#Code to Allow For Buttons
event_info = {
    'type': '',
    'description': '',
    'time': -1
        }


def wait_for_event(timeout=-1, interval=0.001, max_rate=20, allow_interupt=True):    
    start_time= time.time()

    event_info['type'] = ""
    event_info['description'] = ""
    event_info['time'] = -1

    n_proc = int(max_rate*interval)+1
    
    with ui_events() as ui_poll:
        keep_looping = True
        while keep_looping==True:
            ui_poll(n_proc)

            if (timeout != -1) and (time.time() > start_time + timeout):
                keep_looping = False
                
            if allow_interupt==True and event_info['description']!="":
                keep_looping = False
                
            time.sleep(interval)
    
    return event_info

def register_event(btn):
    event_info['type'] = "click"
    event_info['description'] = btn.description
    event_info['time'] = time.time()
    return

#Definitions for button on widgets
btn1 = widgets.Button(description="Left")
btn2 = widgets.Button(description="Right")
btn1.on_click(register_event)
btn2.on_click(register_event)
panel = widgets.HBox([btn1,btn2])



#Function for running ANS_Test
def run_ANS(images):

    #defining msgs
    msg = "Welcome to the ANS Test"
    msg1 = "You will briefly be shown a number of images containing dots of different numerosity."
    msg2 = "The image will appear for a short duration on the screen and you will have 3 seconds to choose the side with the most number of dots"
    msg3 = "Here is an example image"
    msg4 = "Press the 'Left' button to select the left image or the 'Right' button to select the right image."
    msg5 = "The test will run for a total of 3 minutes.\nYou will be shown an image for 0.75 seconds. You then have 3 seconds to choose your answer."
    msg6 = "The test will now begin!\nGood Luck!"

    print(msg)
    time.sleep(2)
   
    print(msg1)
    print(msg2)
    time.sleep(10)
    clear_output(wait = False)

    print(msg3)
    time.sleep(2)
    display(image1)
    print(msg4)
    
    display(panel)
    while True:
        result = wait_for_event(timeout=-1)  # Wait indefinitely
        if result['description'] != "":
            clear_output(wait=False)
            break 
    
    clear_output(wait = False)
    
    print(msg5)
    time.sleep(6)
    clear_output(wait=False)
    
    print(msg6)
    time.sleep(6)
    clear_output(wait=False)

    reaction_time = []
    total_score = 0
    scores = []

    #For loop to go through list of images 
    for image, answer in zip(images, answers): 
        
        time.sleep(1.5) #1.5 wait between trial
        display(image)
        time.sleep(0.75) #image is displayed for 0.75
        clear_output(wait=False)

        start_time = time.time()
        display(panel)

        result = wait_for_event(timeout=3)
        clear_output(wait = False)

        if result['description'] != "":
            response = time.time() - start_time
            reaction_time.append(response)
        else:
            reaction_time.append(0)

        
        if result['description'] == answer: 
            total_score += 1
            scores.append(1)
        else:
            total_score += 0
            scores.append(0)

    avg_reaction_time = sum(reaction_time)/len(reaction_time)
    
    #Output at end of test
    print(f"Your score is {total_score}/30 and your average reaction time is {avg_reaction_time:.4f}")

    return total_score, avg_reaction_time
   

total_score, avg_reaction_time = run_ANS(images)

#Definition for sending results to google forms
def send_to_google_form(data_dict, form_url):
    ''' Helper function to upload information to a corresponding google form 
        You are not expected to follow the code within this function!
    '''
    form_id = form_url[34:90]
    view_form_url = f'https://docs.google.com/forms/d/e/{form_id}/viewform'
    post_form_url = f'https://docs.google.com/forms/d/e/{form_id}/formResponse'

    page = requests.get(view_form_url)
    content = BeautifulSoup(page.content, "html.parser").find('script', type='text/javascript')
    content = content.text[27:-1]
    result = json.loads(content)[1][1]
    form_dict = {}
    
    loaded_all = True
    for item in result:
        if item[1] not in data_dict:
            print(f"Form item {item[1]} not found. Data not uploaded.")
            loaded_all = False
            return False
        form_dict[f'entry.{item[4][0][0]}'] = data_dict[item[1]]
    
    post_result = requests.post(post_form_url, data=form_dict)
    return post_result.ok

data_dict = {
    'User ID': user_id,
    'User Gender': user_gender,
    'User Age': user_age,
    'User Course': user_course,
    'User Tiredness': user_tiredness,
    'Total Score': total_score,
    'Average Reaction Time': avg_reaction_time
    }

form_url = 'https://docs.google.com/forms/d/e/1FAIpQLSf8DU1wKNQ2EKDK_GtPtgF_E1IrR4-aBhtASFa0a1i8q4naHA/viewform'
send_to_google_form(data_dict, form_url)
